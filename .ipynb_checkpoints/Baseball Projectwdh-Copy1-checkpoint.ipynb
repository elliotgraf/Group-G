# %%
#dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats

# %%
#create variable to hold csv file
file_path = "baseball_project.csv"

# %%
# Read our Data file with the pandas library
base_df=pd.read_csv(file_path)
# base_df = base_df.set_index("yearID")
base_df.head()
# Out:
#    yearID lgID teamID franchID divID  Rank   G  Ghome   W   L     ...       \
# 0    1871  NaN    BS1      BNA   NaN     3  31    NaN  20  10     ...
# 1    1871  NaN    CH1      CNA   NaN     2  28    NaN  19   9     ...
# 2    1871  NaN    CL1      CFC   NaN     8  29    NaN  10  19     ...
# 3    1871  NaN    FW1      KEK   NaN     7  19    NaN   7  12     ...
# 4    1871  NaN    NY2      NNA   NaN     5  33    NaN  16  17     ...
#
#    DP     FP                     name                          park  \
# 0  24  0.834     Boston Red Stockings           South End Grounds I
# 1  16  0.829  Chicago White Stockings       Union Base-Ball Grounds
# 2  15  0.818   Cleveland Forest Citys  National Association Grounds
# 3   8  0.803     Fort Wayne Kekiongas                Hamilton Field
# 4  14  0.840         New York Mutuals      Union Grounds (Brooklyn)
#
#    attendance  BPF  PPF  teamIDBR  teamIDlahman45  teamIDretro
# 0         NaN  103   98       BOS             BS1          BS1
# 1         NaN  104  102       CHI             CH1          CH1
# 2         NaN   96  100       CLE             CL1          CL1
# 3         NaN  101  107       KEK             FW1          FW1
# 4         NaN   90   88       NYU             NY2          NY2
#
# [5 rows x 48 columns]

# %%
base_df = base_df[base_df["yearID"]>=2010]
base_df
# Out:
#       yearID lgID teamID franchID divID  Rank    G  Ghome    W    L  \
# 2625    2010   NL    ARI      ARI     W     5  162   81.0   65   97
# 2626    2010   NL    ATL      ATL     E     2  162   81.0   91   71
# 2627    2010   AL    BAL      BAL     E     5  162   81.0   66   96
# 2628    2010   AL    BOS      BOS     E     3  162   81.0   89   73
# 2629    2010   AL    CHA      CHW     C     2  162   81.0   88   74
# 2630    2010   NL    CHN      CHC     C     5  162   81.0   75   87
# 2631    2010   NL    CIN      CIN     C     1  162   81.0   91   71
# 2632    2010   AL    CLE      CLE     C     4  162   81.0   69   93
# 2633    2010   NL    COL      COL     W     3  162   81.0   83   79
# 2634    2010   AL    DET      DET     C     3  162   81.0   81   81
# 2635    2010   NL    FLO      FLA     E     3  162   81.0   80   82
# 2636    2010   NL    HOU      HOU     C     4  162   81.0   76   86
# 2637    2010   AL    KCA      KCR     C     5  162   81.0   67   95
# 2638    2010   AL    LAA      ANA     W     3  162   81.0   80   82
# 2639    2010   NL    LAN      LAD     W     4  162   81.0   80   82
# 2640    2010   NL    MIL      MIL     C     3  162   81.0   77   85
# 2641    2010   AL    MIN      MIN     C     1  162   81.0   94   68
# 2642    2010   AL    NYA      NYY     E     2  162   81.0   95   67
# 2643    2010   NL    NYN      NYM     E     4  162   81.0   79   83
# 2644    2010   AL    OAK      OAK     W     2  162   81.0   81   81
# 2645    2010   NL    PHI      PHI     E     1  162   84.0   97   65
# 2646    2010   NL    PIT      PIT     C     6  162   81.0   57  105
# 2647    2010   NL    SDN      SDP     W     2  162   81.0   90   72
# 2648    2010   AL    SEA      SEA     W     4  162   81.0   61  101
# 2649    2010   NL    SFN      SFG     W     1  162   81.0   92   70
# 2650    2010   NL    SLN      STL     C     2  162   81.0   86   76
# 2651    2010   AL    TBA      TBD     E     1  162   81.0   96   66
# 2652    2010   AL    TEX      TEX     W     1  162   81.0   90   72
# 2653    2010   AL    TOR      TOR     E     4  162   78.0   85   77
# 2654    2010   NL    WAS      WSN     E     5  162   81.0   69   93
# ...      ...  ...    ...      ...   ...   ...  ...    ...  ...  ...
# 2835    2017   NL    ARI      ARI     W     2  162   81.0   93   69
# 2836    2017   NL    ATL      ATL     E     3  162   81.0   72   90
# 2837    2017   AL    BAL      BAL     E     5  162   81.0   75   87
# 2838    2017   AL    BOS      BOS     E     1  162   81.0   93   69
# 2839    2017   AL    CHA      CHW     C     4  162   81.0   67   95
# 2840    2017   NL    CHN      CHC     C     1  162   81.0   92   70
# 2841    2017   NL    CIN      CIN     C     5  162   81.0   68   94
# 2842    2017   AL    CLE      CLE     C     1  162   81.0  102   60
# 2843    2017   NL    COL      COL     W     3  162   81.0   87   75
# 2844    2017   AL    DET      DET     C     5  162   81.0   64   98
# 2845    2017   AL    HOU      HOU     W     1  162   81.0  101   61
# 2846    2017   AL    KCA      KCR     C     3  162   81.0   80   82
# 2847    2017   AL    LAA      ANA     W     2  162   81.0   80   82
# 2848    2017   NL    LAN      LAD     W     1  162   81.0  104   58
# 2849    2017   NL    MIA      FLA     E     2  162   78.0   77   85
# 2850    2017   NL    MIL      MIL     C     2  162   84.0   86   76
# 2851    2017   AL    MIN      MIN     C     2  162   81.0   85   77
# 2852    2017   AL    NYA      NYY     E     2  162   81.0   91   71
# 2853    2017   NL    NYN      NYM     E     4  162   81.0   70   92
# 2854    2017   AL    OAK      OAK     W     5  162   81.0   75   87
# 2855    2017   NL    PHI      PHI     E     5  162   81.0   66   96
# 2856    2017   NL    PIT      PIT     C     4  162   81.0   75   87
# 2857    2017   NL    SDN      SDP     W     4  162   81.0   71   91
# 2858    2017   AL    SEA      SEA     W     3  162   81.0   78   84
# 2859    2017   NL    SFN      SFG     W     5  162   81.0   64   98
# 2860    2017   NL    SLN      STL     C     3  162   81.0   83   79
# 2861    2017   AL    TBA      TBD     E     3  162   81.0   80   82
# 2862    2017   AL    TEX      TEX     W     4  162   81.0   78   84
# 2863    2017   AL    TOR      TOR     E     4  162   81.0   76   86
# 2864    2017   NL    WAS      WSN     E     1  162   81.0   97   65
#
#          ...        DP     FP                           name  \
# 2625     ...       152  0.983           Arizona Diamondbacks
# 2626     ...       166  0.980                 Atlanta Braves
# 2627     ...       141  0.982              Baltimore Orioles
# 2628     ...       132  0.982                 Boston Red Sox
# 2629     ...       158  0.983              Chicago White Sox
# 2630     ...       137  0.979                   Chicago Cubs
# 2631     ...       142  0.988                Cincinnati Reds
# 2632     ...       179  0.982              Cleveland Indians
# 2633     ...       182  0.984               Colorado Rockies
# 2634     ...       171  0.982                 Detroit Tigers
# 2635     ...       130  0.979                Florida Marlins
# 2636     ...       135  0.983                 Houston Astros
# 2637     ...       138  0.980             Kansas City Royals
# 2638     ...       116  0.981  Los Angeles Angels of Anaheim
# 2639     ...       124  0.984            Los Angeles Dodgers
# 2640     ...       142  0.983              Milwaukee Brewers
# 2641     ...       150  0.987                Minnesota Twins
# 2642     ...       161  0.988               New York Yankees
# 2643     ...       159  0.986                  New York Mets
# 2644     ...       147  0.984              Oakland Athletics
# 2645     ...       158  0.986          Philadelphia Phillies
# 2646     ...       120  0.979             Pittsburgh Pirates
# 2647     ...       141  0.988               San Diego Padres
# 2648     ...       145  0.982               Seattle Mariners
# 2649     ...       110  0.988           San Francisco Giants
# 2650     ...       172  0.984            St. Louis Cardinals
# 2651     ...       134  0.986                 Tampa Bay Rays
# 2652     ...       133  0.982                  Texas Rangers
# 2653     ...       172  0.985              Toronto Blue Jays
# 2654     ...       148  0.979           Washington Nationals
# ...      ...       ...    ...                            ...
# 2835     ...       140  0.982           Arizona Diamondbacks
# 2836     ...       137  0.984                 Atlanta Braves
# 2837     ...       175  0.984              Baltimore Orioles
# 2838     ...       126  0.982                 Boston Red Sox
# 2839     ...       157  0.981              Chicago White Sox
# 2840     ...       139  0.984                   Chicago Cubs
# 2841     ...       132  0.986                Cincinnati Reds
# 2842     ...       167  0.987              Cleveland Indians
# 2843     ...       168  0.987               Colorado Rockies
# 2844     ...       146  0.985                 Detroit Tigers
# 2845     ...       153  0.983                 Houston Astros
# 2846     ...       145  0.987             Kansas City Royals
# 2847     ...       135  0.986  Los Angeles Angels of Anaheim
# 2848     ...       131  0.985            Los Angeles Dodgers
# 2849     ...       156  0.988                  Miami Marlins
# 2850     ...       164  0.981              Milwaukee Brewers
# 2851     ...       143  0.987                Minnesota Twins
# 2852     ...       102  0.984               New York Yankees
# 2853     ...       125  0.984                  New York Mets
# 2854     ...       162  0.980              Oakland Athletics
# 2855     ...       145  0.986          Philadelphia Phillies
# 2856     ...       156  0.984             Pittsburgh Pirates
# 2857     ...       177  0.981               San Diego Padres
# 2858     ...       147  0.982               Seattle Mariners
# 2859     ...       127  0.985           San Francisco Giants
# 2860     ...       164  0.984            St. Louis Cardinals
# 2861     ...       129  0.983                 Tampa Bay Rays
# 2862     ...       173  0.982                  Texas Rangers
# 2863     ...       145  0.985              Toronto Blue Jays
# 2864     ...       139  0.985           Washington Nationals
#
#                                  park  attendance  BPF  PPF  teamIDBR  \
# 2625                      Chase Field   2056941.0  104  105       ARI
# 2626                     Turner Field   2510119.0   98   97       ATL
# 2627      Oriole Park at Camden Yards   1733018.0  101  102       BAL
# 2628                   Fenway Park II   3046443.0  106  105       BOS
# 2629              U.S. Cellular Field   2194378.0  105  105       CHW
# 2630                    Wrigley Field   3062973.0  108  108       CHC
# 2631         Great American Ball Park   2060550.0   99   99       CIN
# 2632                     Jacobs Field   1394812.0   93   93       CLE
# 2633                      Coors Field   2875245.0  115  115       COL
# 2634                    Comerica Park   2461237.0  101  101       DET
# 2635                  Dolphin Stadium   1535226.0  105  104       FLA
# 2636                 Minute Maid Park   2331490.0   95   96       HOU
# 2637                 Kauffman Stadium   1615324.0   99  101       KCR
# 2638                    Angel Stadium   3250816.0   98   98       LAA
# 2639                   Dodger Stadium   3562320.0   95   95       LAD
# 2640                      Miller Park   2776531.0   98   98       MIL
# 2641                     Target Field   3223640.0  101  100       MIN
# 2642               Yankee Stadium III   3765807.0  105  103       NYY
# 2643                       Citi Field   2559738.0   97   97       NYM
# 2644  Oakland-Alameda County Coliseum   1418391.0  100  100       OAK
# 2645               Citizens Bank Park   3647249.0  101  100       PHI
# 2646                         PNC Park   1613399.0   99  101       PIT
# 2647                       Petco Park   2131774.0   91   91       SDP
# 2648                     Safeco Field   2085488.0   93   95       SEA
# 2649                        AT&T Park   3037443.0  101  101       SFG
# 2650                Busch Stadium III   3301218.0   97   97       STL
# 2651                  Tropicana Field   1843445.0   96   95       TBR
# 2652    Rangers Ballpark in Arlington   2505171.0  105  104       TEX
# 2653                    Rogers Centre   1625555.0  100  100       TOR
# 2654                   Nationals Park   1828066.0   99  100       WSN
# ...                               ...         ...  ...  ...       ...
# 2835                      Chase Field   2134375.0  110  110       ARI
# 2836                    SunTrust Park   2505252.0   98   98       ATL
# 2837      Oriole Park at Camden Yards   2028424.0   98   99       BAL
# 2838                   Fenway Park II   2917678.0  105  104       BOS
# 2839              U.S. Cellular Field   1629470.0   98   98       CHW
# 2840                    Wrigley Field   3199562.0  102  100       CHC
# 2841         Great American Ball Park   1836917.0  100  101       CIN
# 2842                Progressive Field   2048138.0  106  104       CLE
# 2843                      Coors Field   2953650.0  115  115       COL
# 2844                    Comerica Park   2321599.0  103  104       DET
# 2845                 Minute Maid Park   2403671.0   91   90       HOU
# 2846                 Kauffman Stadium   2220370.0  102  102       KCR
# 2847         Angel Stadium of Anaheim   3019585.0   96   96       LAA
# 2848                   Dodger Stadium   3765856.0   97   96       LAD
# 2849                     Marlins Park   1583014.0   93   93       MIA
# 2850                      Miller Park   2627705.0  101  101       MIL
# 2851                     Target Field   2051279.0   99  100       MIN
# 2852               Yankee Stadium III   3146966.0  104  103       NYY
# 2853                       Citi Field   2460622.0   97   97       NYM
# 2854                    O.co Coliseum   1475721.0   96   97       OAK
# 2855               Citizens Bank Park   1905354.0   96   97       PHI
# 2856                         PNC Park   1919447.0   99   99       PIT
# 2857                       Petco Park   2138491.0   94   95       SDP
# 2858                     Safeco Field   2135445.0   97   97       SEA
# 2859                        AT&T Park   3303652.0   96   96       SFG
# 2860                Busch Stadium III   3447937.0   98   98       STL
# 2861                  Tropicana Field   1253619.0   94   94       TBR
# 2862    Rangers Ballpark in Arlington   2507760.0  107  107       TEX
# 2863                    Rogers Centre   3203886.0  105  105       TOR
# 2864                   Nationals Park   2524980.0  103  102       WSN
#
#       teamIDlahman45  teamIDretro
# 2625             ARI          ARI
# 2626             ATL          ATL
# 2627             BAL          BAL
# 2628             BOS          BOS
# 2629             CHA          CHA
# 2630             CHN          CHN
# 2631             CIN          CIN
# 2632             CLE          CLE
# 2633             COL          COL
# 2634             DET          DET
# 2635             FLO          FLO
# 2636             HOU          HOU
# 2637             KCA          KCA
# 2638             ANA          ANA
# 2639             LAN          LAN
# 2640             ML4          MIL
# 2641             MIN          MIN
# 2642             NYA          NYA
# 2643             NYN          NYN
# 2644             OAK          OAK
# 2645             PHI          PHI
# 2646             PIT          PIT
# 2647             SDN          SDN
# 2648             SEA          SEA
# 2649             SFN          SFN
# 2650             SLN          SLN
# 2651             TBA          TBA
# 2652             TEX          TEX
# 2653             TOR          TOR
# 2654             MON          WAS
# ...              ...          ...
# 2835             ARI          ARI
# 2836             ATL          ATL
# 2837             BAL          BAL
# 2838             BOS          BOS
# 2839             CHA          CHA
# 2840             CHN          CHN
# 2841             CIN          CIN
# 2842             CLE          CLE
# 2843             COL          COL
# 2844             DET          DET
# 2845             HOU          HOU
# 2846             KCA          KCA
# 2847             ANA          ANA
# 2848             LAN          LAN
# 2849             FLO          MIA
# 2850             ML4          MIL
# 2851             MIN          MIN
# 2852             NYA          NYA
# 2853             NYN          NYN
# 2854             OAK          OAK
# 2855             PHI          PHI
# 2856             PIT          PIT
# 2857             SDN          SDN
# 2858             SEA          SEA
# 2859             SFN          SFN
# 2860             SLN          SLN
# 2861             TBA          TBA
# 2862             TEX          TEX
# 2863             TOR          TOR
# 2864             MON          WAS
#
# [240 rows x 48 columns]

# %%
base_df.columns
# Out:
# Index(['yearID', 'lgID', 'teamID', 'franchID', 'divID', 'Rank', 'G', 'Ghome',
#        'W', 'L', 'DivWin', 'WCWin', 'LgWin', 'WSWin', 'R', 'AB', 'H', '2B',
#        '3B', 'HR', 'BB', 'SO', 'SB', 'CS', 'HBP', 'SF', 'RA', 'ER', 'ERA',
#        'CG', 'SHO', 'SV', 'IPouts', 'HA', 'HRA', 'BBA', 'SOA', 'E', 'DP', 'FP',
#        'name', 'park', 'attendance', 'BPF', 'PPF', 'teamIDBR',
#        'teamIDlahman45', 'teamIDretro'],
#       dtype='object')

# %%
hit = base_df.groupby("yearID").mean()["H"]
hit = pd.DataFrame(hit)
hit
# Out:
#                   H
# yearID
# 2010    1418.466667
# 2011    1408.900000
# 2012    1402.100000
# 2013    1403.100000
# 2014    1386.500000
# 2015    1403.533333
# 2016    1409.200000
# 2017    1407.166667

# %%
x_axis = hit.index
y_axis = hit["H"]
plt.bar(x_axis,y_axis)
plt.title("Hit Average")
plt.ylabel("Hits")
plt.xlabel("Years 2010 - 2017")
plt.ylim(1350,1430)
# Out:
# (1350, 1430)

# %%
Runs = base_df.groupby("yearID").mean()["R"]
Runs = pd.DataFrame(Runs)
Runs
# Out:
#                  R
# yearID
# 2010    710.266667
# 2011    693.600000
# 2012    700.566667
# 2013    675.166667
# 2014    658.700000
# 2015    688.233333
# 2016    724.800000
# 2017    752.733333

# %%
x_axis = Runs.index
y_axis = Runs["R"]
plt.bar(x_axis,y_axis)
plt.title("Run Average")
plt.ylabel("Run")
plt.xlabel("Years 2010 - 2017")
plt.ylim(600,775)
# Out:
# (600, 800)

# %%
base_df = base_df[base_df["yearID"]>=2010]
ERA = base_df.groupby("yearID").mean()["ERA"]
ERA = pd.DataFrame(ERA)
ERA
# Out:
#              ERA
# yearID
# 2010    4.073333
# 2011    3.936667
# 2012    4.009333
# 2013    3.863333
# 2014    3.738000
# 2015    3.956333
# 2016    4.184333
# 2017    4.352667

# %%
x_axis = ERA.index
y_axis = ERA["ERA"].mode()
plt.bar(x_axis,y_axis)
plt.title("ERA Average")
plt.ylabel("ERA")
plt.xlabel("Years 2010 - 2017")
plt.ylim(2.5,4.5)
# Out:
# (2.5, 4.5)

# %%
?

# %%
?
