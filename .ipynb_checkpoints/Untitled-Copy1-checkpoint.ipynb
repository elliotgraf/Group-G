# %%
#dependencies
import pandas as pd
import matplotlib.pyplot as plt

# %%
#create variable to hold csv file
file_path = "baseball_project.csv"

# %%
# Read our Data file with the pandas library
base_df=pd.read_csv(file_path)
base_df.head()
# Out:
#    yearID lgID teamID franchID divID  Rank   G  Ghome   W   L     ...       \
# 0    1871  NaN    BS1      BNA   NaN     3  31    NaN  20  10     ...
# 1    1871  NaN    CH1      CNA   NaN     2  28    NaN  19   9     ...
# 2    1871  NaN    CL1      CFC   NaN     8  29    NaN  10  19     ...
# 3    1871  NaN    FW1      KEK   NaN     7  19    NaN   7  12     ...
# 4    1871  NaN    NY2      NNA   NaN     5  33    NaN  16  17     ...
#
#    DP     FP                     name                          park  \
# 0  24  0.834     Boston Red Stockings           South End Grounds I
# 1  16  0.829  Chicago White Stockings       Union Base-Ball Grounds
# 2  15  0.818   Cleveland Forest Citys  National Association Grounds
# 3   8  0.803     Fort Wayne Kekiongas                Hamilton Field
# 4  14  0.840         New York Mutuals      Union Grounds (Brooklyn)
#
#    attendance  BPF  PPF  teamIDBR  teamIDlahman45  teamIDretro
# 0         NaN  103   98       BOS             BS1          BS1
# ...

# %%
#Adjust base_df to show rows(2010 - 2017...break at 2013), columns(name,yearID, H, R, ERA, ER)
base_df[["name","yearID","H","ERA","ER"]]
# Out:
#                                name  yearID     H   ERA   ER
# 0              Boston Red Stockings    1871   426  3.55  109
# 1           Chicago White Stockings    1871   323  2.76   77
# 2            Cleveland Forest Citys    1871   328  4.11  116
# 3              Fort Wayne Kekiongas    1871   178  5.17   97
# 4                  New York Mutuals    1871   403  3.72  121
# 5            Philadelphia Athletics    1871   410  4.95  137
# 6             Rockford Forest Citys    1871   274  4.30  108
# 7                    Troy Haymakers    1871   384  5.51  153
# 8               Washington Olympics    1871   375  4.37  137
# 9                Baltimore Canaries    1872   753  2.90  166
# 10                Brooklyn Eckfords    1872   248  5.55  160
# 11               Brooklyn Atlantics    1872   377  4.53  169
# 12             Boston Red Stockings    1872   673  1.86   89
# 13           Cleveland Forest Citys    1872   272  5.70  126
# ...
